# %% [markdown]
# # Resource: MQ Sequencing Tech 2025.pdf
# This notebook is a high-fidelity conversion of the original PDF slide deck.

# %% [markdown]
# ![Slide 1](rendered_slides/MQ_Tech_Full-001.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Sequencing Technologies
#
#        Michael Quail
#        mq1@sanger.ac.uk -->

# %% [markdown]
# ![Slide 2](rendered_slides/MQ_Tech_Full-002.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Short Read
#                 Sequencers
#                                               Illumina
#                                               Nextseq
#
# Omniome
#
#
#
#
#           Element   Ultima UG100
#                                    Singular
#                                    S4 -->

# %% [markdown]
# ![Slide 3](rendered_slides/MQ_Tech_Full-003.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Long Read Sequencers
#
#
#                                   Oxford Nanopore P48
#
#     PacBio Revio
#                                                                      Oxford Nanopore gridION
#
#
#
#
#                                             Oxford Nanopore minION
#
#                     PacBio Vega
#
#
#
# Generate much longer reads that enable more of the genome to be covered
# Generally more expensive than short read, with higher input requirements,
# Single molecule so yields dependent on DNA quality -->

# %% [markdown]
# ![Slide 4](rendered_slides/MQ_Tech_Full-004.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Sanger Sequencing -->

# %% [markdown]
# ![Slide 5](rendered_slides/MQ_Tech_Full-005.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Frederick Sanger
#
# » Discovered DNA sequencing by chain
#   termination method
# » Nobel Prize 1 (1958)
#   » Complete amino acid
#     sequence of insulin
# » Nobel Prize 2 (1980)
#   » For DNA sequencing -->

# %% [markdown]
# ![Slide 6](rendered_slides/MQ_Tech_Full-006.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Primer Extension
#                              DNA Polymerase
#
#
#            Primer
#
#                dATP
#                dGTP
#                dCTP
#                dGTP
#
#                Nucleotides       NEW
#                                  STRAND
#
#
#
#
# Template DNA -->

# %% [markdown]
# ![Slide 7](rendered_slides/MQ_Tech_Full-007.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Dideoxy Nucleotides
#
#
# • Lack an -OH group at the 3-
#     carbon position
# •   Cannot add another
#     nucleoside at that position
# •   Prevent further DNA
#     synthesis -->

# %% [markdown]
# ![Slide 8](rendered_slides/MQ_Tech_Full-008.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- All Possible Terminations -->

# %% [markdown]
# ![Slide 9](rendered_slides/MQ_Tech_Full-009.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Original Sanger Sequencing
# » 4 sequencing reactions performed for each
#   template, each with different terminator
# » Radioactive primer or nucleotide used
# » Sequencing reactions run on <1mm
#   polyacrylamide gel cast between two glass
#   plates to separate fragments according to
#   size
# » After run gel exposed to film and
#   developed to reveal image -->

# %% [markdown]
# ![Slide 10](rendered_slides/MQ_Tech_Full-010.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Sequencing gel autorad -->

# %% [markdown]
# ![Slide 11](rendered_slides/MQ_Tech_Full-011.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Fluorescent Terminators -->

# %% [markdown]
# ![Slide 12](rendered_slides/MQ_Tech_Full-012.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Fluorescent Gel Sequencing -->

# %% [markdown]
# ![Slide 13](rendered_slides/MQ_Tech_Full-013.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ABI Capillary 3730 -->

# %% [markdown]
# ![Slide 14](rendered_slides/MQ_Tech_Full-014.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- DNA Sequence Files -->

# %% [markdown]
# ![Slide 15](rendered_slides/MQ_Tech_Full-015.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Error
#
# » Sequence quality Q is reported on a log scale
# » Q10 is 1 error in 10
# » Q20 is 1 error in 100
# » Q30 is 1 error in 1000
# » Q40 is 1 error in 10000
# » Q50 is 1 error in 100000 -->

# %% [markdown]
# ![Slide 16](rendered_slides/MQ_Tech_Full-016.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Capillary sequencing
# » Individual reactions -> 96 capillary array
# » PCR errors
# » Cloning bias
# » 1000-base reads
# » 1-2 hour run time
# » Accurate, Q30
# » Low cost if want 1 read
# » Low throughput, expensive to sequence
# whole genomes -->

# %% [markdown]
# ![Slide 17](rendered_slides/MQ_Tech_Full-017.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Next Generation sequencing
#
#        Is massively parallel
# Not limited to few reactions per run -->

# %% [markdown]
# ![Slide 18](rendered_slides/MQ_Tech_Full-018.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Next-Generation Sequencing
#
#
#
#
# 1 feature         1 chip,thousands or
# 1 template        millions of features
#                   Output Mb-Tb -->

# %% [markdown]
# ![Slide 19](rendered_slides/MQ_Tech_Full-019.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Library prep
#
#
#
#
# • Library -->

# %% [markdown]
# ![Slide 20](rendered_slides/MQ_Tech_Full-020.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- • Library -->

# %% [markdown]
# ![Slide 21](rendered_slides/MQ_Tech_Full-021.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- • Illumina Library
#
#
#
#
#   P5
#
#
#
#                        R1       R2                    P7
#   Flowcell annealing
#                        Primer   Primer site
#                        site                   Flowcell annealing -->

# %% [markdown]
# ![Slide 22](rendered_slides/MQ_Tech_Full-022.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- • Illumina Library
#
#
#
#
#   P5                   i5                      i7
#
#
#
#                             R1       R2                     P7
#   Flowcell annealing
#                             Primer   Primer site
#                             site                    Flowcell annealing -->

# %% [markdown]
# ![Slide 23](rendered_slides/MQ_Tech_Full-023.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Library Prep Approaches
#
# 1. Classical adapter ligation method
#
# 2. Transposon mediated
#
# 3. Inclusion of adapter sequences during
#    PCR -->

# %% [markdown]
# ![Slide 24](rendered_slides/MQ_Tech_Full-024.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Illumina Paired End
# 5’
#                                 Library Prep
#                         P
#
#
#           T                 5’                         A
#           P
#                     +       A                          5’
#                                                             P
#
#
#
# 3’                                       T4 DNA Ligase
#                                                                                      R1 sequencing primer
#
#               5’                                                      3’
#
#
#                                  T                       A
#                                                          T
#                              A
#
#                                                                                      Reverse compliment of R2 primer
#                                                                       5’
#               3’
#
#                    P5                    Hybridize primers
#
#
#               5’                                                      3’   P7
#
#
#                              T                           A
#                                                          T
#                              A
#
#
#                                                                       5’
#               3’
#                                          Limited PCR
#
#
#
#
#      5’                              T                      A                   3’
#      3’                              A                      T                   5’
#
#                                          Make clusters and sequence -->

# %% [markdown]
# ![Slide 25](rendered_slides/MQ_Tech_Full-025.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Nextera -->

# %% [markdown]
# ![Slide 26](rendered_slides/MQ_Tech_Full-026.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Amplicon sequencing -->

# %% [markdown]
# ![Slide 27](rendered_slides/MQ_Tech_Full-027.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 454 -->

# %% [markdown]
# ![Slide 28](rendered_slides/MQ_Tech_Full-028.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 454
#
# » Started NGS (2005)
# » First massively parallel sequencer
# » Bought by Roche in 2007. Now
#   discontinued
# » Based on pyrosequencing of bead-
#   bound DNA in microwells
# » Fore-runner of Ion Torrent and
#   Genapsys -->

# %% [markdown]
# ![Slide 29](rendered_slides/MQ_Tech_Full-029.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 454/Roche Summary
#
# » .7 Gb / run
# » 700 base reads
# » <24 hour run time
# » $7,000 / Gb
#
#
#
# Roche discontinued in 2016 – Too expensive -->

# %% [markdown]
# ![Slide 30](rendered_slides/MQ_Tech_Full-030.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Pyrosequencing
#
#
#
#
# » The incorporation of new bases releases inorganic pyrophosphate
#
#  » A chemical cascade converts luciferin to oxy-luciferin + light -->

# %% [markdown]
# ![Slide 31](rendered_slides/MQ_Tech_Full-031.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Depositing DNA Beads into the PicoTiter™Plate
#
#                                    Load Enzyme Beads
#
# Load beads into
# PicoTiter™Plate
#
#
#
#
#                                    Centrifugation
#
#
#
#
#                   44 μm -->

# %% [markdown]
# ![Slide 32](rendered_slides/MQ_Tech_Full-032.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 454 Technology - Sequencing Instrument -->

# %% [markdown]
# ![Slide 33](rendered_slides/MQ_Tech_Full-033.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 454 Data Example -->

# %% [markdown]
# ![Slide 34](rendered_slides/MQ_Tech_Full-034.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 454/Roche Summary
# » Long read lengths – good for amplicons and de-novo
# sequencing
# » High error rate near homopolymers
# » Single end only
# » .7 Gb / run
# » 700-1000 base reads
# » <24 hour run time
# » $7,000 / Gb
#
#
#
# Roche discontinued in 2016 – Too expensive -->

# %% [markdown]
# ![Slide 35](rendered_slides/MQ_Tech_Full-035.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Other Flow technologies
#
# » Ion Torrent. As 454 but detects the H+
#   released as a base is incorporated.
#
#
#
# » Genapsys. As 454 but detects increase in
#   impedence as a base is incorporated. -->

# %% [markdown]
# ![Slide 36](rendered_slides/MQ_Tech_Full-036.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion Torrent’s PGM
#
#
#
#
# Capital cost $50,000 -->

# %% [markdown]
# ![Slide 37](rendered_slides/MQ_Tech_Full-037.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion Torrent
# » Similar to 454 but detects H+ released as a base is
#   added
#
# » Prone to errors near homopolymers
#
# » Not good for whole genome sequencing but useful
#   for targeted sequencing as run times are short
#
# » Used in a lot of clinical settings for disease panel
#   sequencing -->

# %% [markdown]
# ![Slide 38](rendered_slides/MQ_Tech_Full-038.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion Torrent’s Technology
#                    DNA
#                 polymerase
#                 nucleotides
#                                                 well
#                                             ion-sensing layer
#                                             electronics layer
#
#    DNA(n)+ nucl. = DNA(n+1) + PPi -> PPi + H+
#
#       Flow through A then T then ... like 454 -->

# %% [markdown]
# ![Slide 39](rendered_slides/MQ_Tech_Full-039.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion Torrent Chip Drawing -->

# %% [markdown]
# ![Slide 40](rendered_slides/MQ_Tech_Full-040.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion Torrent
# » Library prep like original 454
# » Amplification on beads by emPCR
# » CMOS chip detection
# » Cyclic addition sequencing - pH changes
# » Not single-molecule -->

# %% [markdown]
# ![Slide 41](rendered_slides/MQ_Tech_Full-041.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 42](rendered_slides/MQ_Tech_Full-042.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion AmpliSeq On-Demand Panels | Now 5,000 Pre-Designed, Pre-Tested Genes Available
#
#                          Expanded Gene Content Across Disease Research Areas
#                   2500
#
#                   2000
#      # of Genes
#
#
#
#
#                   1500
#
#                   1000
#
#                    500
#
#                      0
#
#
#
#
#                          Average of 1154 genes per major UMLS disease research area category
#                                         For Research Use Only. Not for use in diagnostic procedures.
#
#
#
#
# 42 -->

# %% [markdown]
# ![Slide 43](rendered_slides/MQ_Tech_Full-043.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ion GeneStudio S5 Series | Flexible Portfolio Configurable to Your Needs
#
#
#
#
#               Ion GeneStudio™ S5                                                     Ion GeneStudio™ S5 Plus              Ion GeneStudio™ S5 Prime
#
#                                                                                                        New                       New
#
#
#
#
#                              Fast.                                                                Flexible.                    Powerful
#                                                                                                                                   .
#                                                                                                                                             New
#
#
#
#
#       Ion 510™                                  Ion 520™                                 Ion 530™ Chip         Ion 540™ Chip            Ion 550™ Chip
#          Chip                                      Chip                                  15–20 M reads         60–80 M reads           100–130 M reads
#      2–3 M reads                               3–6 M reads                                Up to 600 bp          Up to 200 bp             Up to 200 bp
#      Up to 400 bp                              Up to 600 bp
#      For Research Use Only. Not for use in diagnostic procedures. * Throughputs based on 200bp sequencing
#
#
#
#
# 43 -->

# %% [markdown]
# ![Slide 44](rendered_slides/MQ_Tech_Full-044.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Output and Turn-Around Time to Meet Your Lab’s Peak Volume Needs
#
#
#
#
#                                                                 Ion GeneStudio™ S5       Ion GeneStudio™ S5 Plus   Ion GeneStudio™ S5 Prime
#
#
#
#
#                   Speed*                                                      19 hrs              10 hrs                    6.5 hrs
#
#
#         Output (max/day):                                                   15 Gb/80 M        30 Gb/160 M                50 Gb/260 M
#
#
#          Chips (max/day):                                                    1 x 540        2 x 540 or 1 x 550             2 x 550
#
#  * Based off 540 chip – sequencing (2.5 hours) and analysis (varies) time
#
#
#
#      For Research Use Only. Not for use in diagnostic procedures.
#
#
#
#
# 44 -->

# %% [markdown]
# ![Slide 45](rendered_slides/MQ_Tech_Full-045.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- $299k
#      12-15M reads
#
#
#
#
# 45 -->

# %% [markdown]
# ![Slide 46](rendered_slides/MQ_Tech_Full-046.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 46 -->

# %% [markdown]
# ![Slide 47](rendered_slides/MQ_Tech_Full-047.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Sequencing by Synthesis
#
# with florescence detection -->

# %% [markdown]
# ![Slide 48](rendered_slides/MQ_Tech_Full-048.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Illumina -->

# %% [markdown]
# ![Slide 49](rendered_slides/MQ_Tech_Full-049.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Illumina Library Insert sizes
#           Exome, targeted, ChiP, ATAC
#      P5               SP 1          100-200bp
#
#
#                                                  SP2                         P7
#                       Primer site
#                                                  Primer site
#
# Reads need to be just long enough to map and ideally not to overlap exon boundaries
#
#
#
#
#     Whole Genome
#      P5               SP 1           400-600bp                                    P7
#
#
#                                                                SP2
#                       Primer site
#                                                                Primer site
#
#     Fragments need to be just long to span common repeat elements eg AluI
#     with unique sequence on either side so can map -->

# %% [markdown]
# ![Slide 50](rendered_slides/MQ_Tech_Full-050.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 51](rendered_slides/MQ_Tech_Full-051.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 52](rendered_slides/MQ_Tech_Full-052.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- iSeq100, HiSeq4000, Xten, NovaSeq -->

# %% [markdown]
# ![Slide 53](rendered_slides/MQ_Tech_Full-053.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Since 2016 Illumina flowcells have been patterned
# with clusters formed in a defined array of wells -->

# %% [markdown]
# ![Slide 54](rendered_slides/MQ_Tech_Full-054.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 55](rendered_slides/MQ_Tech_Full-055.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ExAmp -->

# %% [markdown]
# ![Slide 56](rendered_slides/MQ_Tech_Full-056.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 57](rendered_slides/MQ_Tech_Full-057.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 58](rendered_slides/MQ_Tech_Full-058.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 59](rendered_slides/MQ_Tech_Full-059.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 60](rendered_slides/MQ_Tech_Full-060.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Sequencing by Synthesis
#
#          » Extend by 1 base
#
#          » Image
#
#
#          » Reverse
#            termination
#
#
#          » Repeat -->

# %% [markdown]
# ![Slide 61](rendered_slides/MQ_Tech_Full-061.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Illumina Modified Nucleotides
#                                  PPP        5’       Base
#                  Natural dNTP:                   O
#
#
#
#
#                                        3’   OH
#
#
#
#
# Reversible florescent dTTP: -->

# %% [markdown]
# ![Slide 62](rendered_slides/MQ_Tech_Full-062.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 63](rendered_slides/MQ_Tech_Full-063.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 64](rendered_slides/MQ_Tech_Full-064.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 65](rendered_slides/MQ_Tech_Full-065.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Error
#
# » Sequence quality Q is reported on a log scale
# » Q10 is 1 error in 10
# » Q20 is 1 error in 100
# » Q30 is 1 error in 1000
# » Q40 is 1 error in 10000
# » Q50 is 1 error in 100000 -->

# %% [markdown]
# ![Slide 66](rendered_slides/MQ_Tech_Full-066.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Error limits read length -->

# %% [markdown]
# ![Slide 67](rendered_slides/MQ_Tech_Full-067.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Illumina sequencing
#          with indexing
# With Illumina sequencing you sequence the insert from
#    each end. And you can also perform sequencing
#  reactions that read the sequence of the index in the
#         introduced adapter. So how is this done -->

# %% [markdown]
# ![Slide 68](rendered_slides/MQ_Tech_Full-068.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 69](rendered_slides/MQ_Tech_Full-069.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Economics of Illumina ’s Sequencing Portfolio
#
#
# Platform       Flow Cell   $/G                              $/G
#                            (300 CYC.)
#                                                           (300 CYC.)
#
#
#                10B         $3
# Novaseq X/X+
#                25B         $2
#
#                S4          $5
# NovaSeq 6000
#                SP          $15.40
#
#
# NextSeq 2000   P3          $20.00
#
#
# NextSeq
#                P2          $29.50
# 1000/2000
#
#
# NextSeq 550    HO          $41.38
#
#
#
# NextSeq 550    MO          $47.50
#
#
#
# MiSeq          v2          $236.00
#
#
#                                         $0   $50   $100       $150     $200 -->

# %% [markdown]
# ![Slide 70](rendered_slides/MQ_Tech_Full-070.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 71](rendered_slides/MQ_Tech_Full-071.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- MiSeq i100 -->

# %% [markdown]
# ![Slide 72](rendered_slides/MQ_Tech_Full-072.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Illumina
#
# » Cheap $2-$300/Gb
# » Highly accurate data mostly Q30
# » Massively parallel. Millions/billions of
#   reads
# » Short read -->

# %% [markdown]
# ![Slide 73](rendered_slides/MQ_Tech_Full-073.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- The ownership of this material belongs to MGI，and without the permission of the owner, it shall not be directly release
# or disclosed.
#
#
# MGI All Rights Reserved Dissemination，distribution and copying is prohibited without authorization. -->

# %% [markdown]
# ![Slide 74](rendered_slides/MQ_Tech_Full-074.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 75](rendered_slides/MQ_Tech_Full-075.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 76](rendered_slides/MQ_Tech_Full-076.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 77](rendered_slides/MQ_Tech_Full-077.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- MGI sequencing chemistry
# DNA nanoballs and cool MPS -->

# %% [markdown]
# ![Slide 78](rendered_slides/MQ_Tech_Full-078.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 79](rendered_slides/MQ_Tech_Full-079.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 80](rendered_slides/MQ_Tech_Full-080.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- DNBseq-T1+
#
#
#
#
# 12Tb in 22 hours
# Approx $2/Gb
# Upto PE300 -->

# %% [markdown]
# ![Slide 81](rendered_slides/MQ_Tech_Full-081.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- New
#            Sequencers
#                                            Illumina
#                                            Chemistry X
#
# Onso
#
#
#
#                  Ultima UG100
#
#
#
#
#        Element
#
#                                       Singular
#                                       S4
#
#
#                                 MGI -->

# %% [markdown]
# ![Slide 82](rendered_slides/MQ_Tech_Full-082.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Comparison Table
#                  Illumina        Illumina         Ultima UG100    Element Aviti       Singular G4       PacBio SBB
#                  Novaseq         Nextseq
#
# Instrument       $1.25M          $335k            $1.5M           $289k ($249K)       $350k             $99K
#
# $/Gb             3 (10B), 2      20 (9 in 2024)   1               2-5                 8-10              4-12
#                  (25B)
#
# Accuracy         QQQ             QQQ              QQQ             QQQQ                QQQ               QQQQQ
#
# Max read         2x150 (SP)      2x300            300 SE          2x300               2x150             200SE
# length
#
# Run Time for     24 hrs          48 hrs           18 hrs          48 hrs              19 hrs            48hrs
# 2x150 or 1x300
#
# Flowcells        2               2                2               2                   4                 2
#
# Yield/run        6000Gb,         30-360Gb         >4000Gb         480Gb               360Gb             150Gb
#                  16000Gb
#
# Other            Infinity long   Infinity long                    Non patterned,                        Non patterned
#                  reads           reads                            loop long reads
#
# Use case                                          Cheap           -high plex levels   Flexibility via   High accuracy
#                                                   sequence for    –low                independent       applications,
#                                                   big data        complexity          flowcells         high plex
#                                                   applications,   -long reads                           potential -->

# %% [markdown]
# ![Slide 83](rendered_slides/MQ_Tech_Full-083.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Element AVITI™
# ● ~$335K. $249K each if you order 3
#
# ● $2-$5/Gb. $1680 for 200-300Gb
#
# ● 2 flowcells. 2 x 150. 90% >Q40
#
# ● 2 x 300 available
#
# ● Sequencing by binding on RCA amplified template
#
# ● Loop synthetic long read
#
# ● Low duplicates
#
# ● No index hopping allowing for combinatorial indexing
#
# ● Better results with low complexity sequencing
#
# ● Can have long inserts >2kb
#
#
#
#
# Images provided by Element Biosciences -->

# %% [markdown]
# ![Slide 84](rendered_slides/MQ_Tech_Full-084.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Element Kits -->

# %% [markdown]
# ![Slide 85](rendered_slides/MQ_Tech_Full-085.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Avidity base chemistry (ABC)
#
#
#
#
# Content and Images provided by Element Biosciences -->

# %% [markdown]
# ![Slide 86](rendered_slides/MQ_Tech_Full-086.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- AVITI System Architecture Enables
# Maximum Run Flexibility
#    Dual Independent Flow Cells       Individually Addressible Lanes
#
#
#
#
#     Perform two parallel runs with   Sequence separate libraries or
#       different run parameters         pools on a single flow cell -->

# %% [markdown]
# ![Slide 87](rendered_slides/MQ_Tech_Full-087.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Cloudbreak Freestyle
#
#
#
#
# Content and Images provided by Element Biosciences -->

# %% [markdown]
# ![Slide 88](rendered_slides/MQ_Tech_Full-088.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Achieving Q50 with UltraQ
#
#
#
#
# Content and Images provided by Element Biosciences -->

# %% [markdown]
# ![Slide 89](rendered_slides/MQ_Tech_Full-089.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Trinity: On Flow cell
#                 hybrid capture
#
#
#
#
# Content and Images provided by Element Biosciences -->

# %% [markdown]
# ![Slide 90](rendered_slides/MQ_Tech_Full-090.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Expert Mode HD: 20-70% more data
# for FREE with higher polony density
#
#
#
#
# Content and Images provided by Element Biosciences -->

# %% [markdown]
# ![Slide 91](rendered_slides/MQ_Tech_Full-091.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Singular Genomics
#
#
# ●$10-$15/Gb
# ●2 x 150 in 19 hours
# ●4 x 4 lane flowcells. Each flowcell can be run and loaded
#   independently.
# ●Uses similar SBS and clustering to Illumina
# ●No index hopping. No issue with low complexity -->

# %% [markdown]
# ![Slide 92](rendered_slides/MQ_Tech_Full-092.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- 2
#
#
#
#
#     Ultima -->

# %% [markdown]
# ![Slide 93](rendered_slides/MQ_Tech_Full-093.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Ultima
# • $100 genome. $1/Gb
# • SE 300 in ~14hr
# • Flow based.
# • Some indel errors around homopolymers
# • 89% Q30
# • Flow based sequencing on a 10” spinning disc -->

# %% [markdown]
# ![Slide 94](rendered_slides/MQ_Tech_Full-094.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Revolutionary new sequencing hardware
#
#                             Camera
#
#
#
#
#         Reagent dispenser
#
#                                                     Spinning wafer on instrument
#                                                                                    •   Low cost (standard substrate)
#
# Wafer
#                                                                                    •   ~10B reads per wafer (x2)
#
#
#                                                                                    •   Fast and efficient reagent delivery
#
#
#                                                                                    •   “Air gap” minimized contamination
#
#
#                                                                                    •   Rotational optical scanning
#
#
#
#
#                                                                                                                              Proprietary and Confidential -->

# %% [markdown]
# ![Slide 95](rendered_slides/MQ_Tech_Full-095.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- A novel spin on sequencing chemistry
#                                                  mnSBS
#
#   Flow Chemistry                           Terminated chemistry   Mostly natural sequencing by synthesis
#
#                       Diffusion
#
#
#
#
#                                                                                                             Labeled
#
#
#
#
#                                                                                                                  Unlabeled
#
#
#
#
# Natural nucleotides                      Reversible terminator     Fluorescently labeled                      Mostly natural
#
#
#
#
#                                                                    Long read length
#                                                                    Fast cycle time
#                                                                    Accurate
#                                                                    Scalable
#                                                                    Low cost
# Transient detection                      End point detection
#
# Static sensor                            Scanning
#
#
#
#
#                                                                                                            Proprietary and Confidential -->

# %% [markdown]
# ![Slide 96](rendered_slides/MQ_Tech_Full-096.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Mostly natural chemistry combines advantages of
#            flow chemistry with optical scanning
#                                                       Median signals vs. homopolymer
#
#
#
#
#                                                                           homopolymer level
#
#
#
#
# • Majority nucleotides unlabeled to avoid quenching   • Endpoint detection significantly improves accuracy
# • Minimal scarring supports longer reads              • Maintain signal linearity to at least homopolymer length 12
# • Faster runs via 2min wash->image->cleave cycle      • Machine learning accounts for sequence context -->

# %% [markdown]
# ![Slide 97](rendered_slides/MQ_Tech_Full-097.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Mostly natural chemistry combines advantages of
#                flow chemistry with optical scanning
#                                                         Median signals vs. homopolymer
#
#
#
#
#                                                                                      homopolymer level
#
#
#
# •   Majority nucleotides unlabeled to avoid quenching   •   Endpoint detection significantly improves accuracy
# •   Minimal scarring supports longer reads              •   Maintain signal linearity to at least homopolymer length 12
# •   Faster runs via 2min wash->image->cleave cycle      •   Machine learning accounts for sequence context
#
#
#
#
#                                                                                                                           Proprietary and Confidential -->

# %% [markdown]
# ![Slide 98](rendered_slides/MQ_Tech_Full-098.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Mostly natural chemistry combines advantages of
#                 flow chemistry with optical scanning
#                                                         Median signals vs. homopolymer
#
#
#
#
#                                                                                      homopolymer level
#
#
#
# •   Majority nucleotides unlabeled to avoid quenching   •   Endpoint detection significantly improves accuracy
# •   Minimal scarring supports longer reads              •   Maintain signal linearity to at least homopolymer length 12
# •   Faster runs via 2min wash->image->cleave cycle      •   Machine learning accounts for sequence context
#
#
#
#
#                                                                                                                           Proprietary and Confidential -->

# %% [markdown]
# ![Slide 99](rendered_slides/MQ_Tech_Full-099.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Mostly natural chemistry combines advantages of
#                flow chemistry with optical scanning
#                                                         Median signals vs. homopolymer
#
#
#
#
#                                                                               homopolymer level
#
#
#
#
# •   Majority nucleotides unlabeled to avoid quenching   •   Endpoint detection significantly improves accuracy
# •   Minimal scarring supports longer reads              •   Maintain signal linearity to at least homopolymer length 12
# •   Faster runs via 2min wash->image->cleave cycle      •   Machine learning accounts for sequence context
#
#
#                                                                                                                           Proprietary and Confidential -->

# %% [markdown]
# ![Slide 100](rendered_slides/MQ_Tech_Full-100.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 101](rendered_slides/MQ_Tech_Full-101.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PPM seq – 1 in a million VAF
#         accuracy -->

# %% [markdown]
# ![Slide 102](rendered_slides/MQ_Tech_Full-102.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PPM seq- library prep -->

# %% [markdown]
# ![Slide 103](rendered_slides/MQ_Tech_Full-103.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Roche SBX
#
# - Nanopore sequencer enabled
#  by acqusition of Genia and Stratos
#
# - Launch 2026
# - 500Mb/sec
# - 15B reads in 4 hours
# - 7B in 1 hour – fast mode
# - Q39 for duplex libraries (200-
#   300bp)
# - Q23 for simplex (200-1500bp)
#
# - Instrument $400-$600k?
#
# - Consumable pricing = competitive
#
# - Read the paper
# DOI: 10.1101/2025.02.19.639056 -->

# %% [markdown]
# ![Slide 104](rendered_slides/MQ_Tech_Full-104.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 105](rendered_slides/MQ_Tech_Full-105.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 106](rendered_slides/MQ_Tech_Full-106.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Libraries are converted to expandomers
#   Bases copied as XNTPs (50x bigger) -->

# %% [markdown]
# ![Slide 107](rendered_slides/MQ_Tech_Full-107.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 108](rendered_slides/MQ_Tech_Full-108.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 109](rendered_slides/MQ_Tech_Full-109.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 110](rendered_slides/MQ_Tech_Full-110.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 111](rendered_slides/MQ_Tech_Full-111.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Long Read Sequencers
#
#
#
#                Oxford Nanopore flongle        Oxford Nanopore minION         Oxford Nanopore gridION
#
#
#
#
# PacBio Revio
#
#
#
#                     Oxford Nanopore P2 Solo
#                                                        Oxford Nanopore P48 -->

# %% [markdown]
# ![Slide 112](rendered_slides/MQ_Tech_Full-112.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Why Long Read
#
# » Potential for higher diagnostic rate
#
# » More complete coverage of genome
#
# » Better assembly
#
# » Haplotype linkage
#
# » Simultaneous modified base detection -->

# %% [markdown]
# ![Slide 113](rendered_slides/MQ_Tech_Full-113.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Long Read Platform Comparison -->

# %% [markdown]
# ![Slide 114](rendered_slides/MQ_Tech_Full-114.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Pacific Biosciences
#
#
#
#
# Onso                     Revio
# » Short Read sequencer   » Long Read sequencer -->

# %% [markdown]
# ![Slide 115](rendered_slides/MQ_Tech_Full-115.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PacBio Long Read
#
# » Long Read Platforms
#   RS>RSII>Sequel>SequelII>Revio
#
# » SMRT. Single Molecule Real Time
#
# » 3rd generation? -->

# %% [markdown]
# ![Slide 116](rendered_slides/MQ_Tech_Full-116.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Pacific Biosciences
# Sequel II/IIe (2018-2022)
#          » 8 million ZMWs/SMRT
#          » $495K/$525 instrument -->

# %% [markdown]
# ![Slide 117](rendered_slides/MQ_Tech_Full-117.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Learn more:
#
#
#
#
# » Revio system
# Throughput
#
#
#
#             480 Gb                                                  24 hour
#             HiFi yield per run with SPRQ                            Sequencing time
#
#
#
#
#             1,300 30x genomes / year
#             2600 per year ta 20x
#
#
#
#
#                                                                                       List price, USD
#                                                                                                         $995/genome at 30x*
#    * $995 for sequencing reagents for one Revio SMRT Cell, which has an
#                                                                                       $599,000
#                                                                                                         <$500 at 20x
#    expected yield of 90 Gb, equivalent to a 30× human genome. Expected
#    pricing subject to change, your local sales representative can provide
#    detailed pricing in your currency.
#                                                                                                                               117 -->

# %% [markdown]
# ![Slide 118](rendered_slides/MQ_Tech_Full-118.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Nov’ 24 Low Throughput Benchtop -->

# %% [markdown]
# ![Slide 119](rendered_slides/MQ_Tech_Full-119.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Pac Bio Technology
#
#
#
#
#        Individual ZMW                Laser light illuminates the ZMW
#
#
#
#
# ZMW with DNA polymerase               ZMW with polymerase + nucs. -->

# %% [markdown]
# ![Slide 120](rendered_slides/MQ_Tech_Full-120.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PacBio Template Preparation
#
#
#
#
# 1   Anneal primer
#
# 2   Bind polymerase
#
# 3   Sequence -->

# %% [markdown]
# ![Slide 121](rendered_slides/MQ_Tech_Full-121.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PacBio Sequencing -->

# %% [markdown]
# ![Slide 122](rendered_slides/MQ_Tech_Full-122.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PacBio Sequencing
#
#
#      » Some bases added very
#        quickly and missed
#      » Some wrong bases flirt with
#        active site and go away
#      » SMRT cell has millions of
#        ZMWs (8M Sequel, 25M
#        Revio) -->

# %% [markdown]
# ![Slide 123](rendered_slides/MQ_Tech_Full-123.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Revio Polymerase Read Lengths -->

# %% [markdown]
# ![Slide 124](rendered_slides/MQ_Tech_Full-124.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 125](rendered_slides/MQ_Tech_Full-125.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Accuracy -->

# %% [markdown]
# ![Slide 126](rendered_slides/MQ_Tech_Full-126.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Long read can access 193 medically
# relevant genes that short read cannot -->

# %% [markdown]
# ![Slide 127](rendered_slides/MQ_Tech_Full-127.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 128](rendered_slides/MQ_Tech_Full-128.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Epigenetics -->

# %% [markdown]
# ![Slide 129](rendered_slides/MQ_Tech_Full-129.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Base Modifications -->

# %% [markdown]
# ![Slide 130](rendered_slides/MQ_Tech_Full-130.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- DETECTION OF DNA BASE MODIFICATIONS USING KINETICS
#
#             Example: N6-methyladenine
#
#
#
#
# •   SMRT Sequencing uses kinetic information from each nucleotide addition to call bases
# •   This same information can be used to distinguish modified and native bases by comparing results of SMRT Sequencing to an in silico
#     kinetic reference for incorporation dynamics without modifications.
#
#
#
#
#                                                                                            Flusberg et al. (2010) Nature Methods 7: 461-465 -->

# %% [markdown]
# ![Slide 131](rendered_slides/MQ_Tech_Full-131.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Revio variant calling and                                          Accuracy, F1%
#
# methylation performance        100
#                                             99.95     99.95            99.41     99.44
#                                                                                                   95.19     95.59
#
#                                  80
#
#
#
#                                  60
#
#
#
#                                  40
#
#
#
#                                  20
#   +5mC
#
#
#
#
#                                    0
#                                                 SNVs                       Indels                       SVs
#
#                                                        Sequel IIe system            Revio system
#
#
#              PEG3
#                             HG002 at maternally imprinted PEG3 locus
#                             Data for internal beta testing https://downloads.pacbcloud.com/public/revio/2022Q4/HG002-
#                             rep3/analysis/HG002.m84005_220827_014912_s1.GRCh38.bam
#                             Variant calling measured against Genome in a Bottle benchmarks, HG002                       131 -->

# %% [markdown]
# ![Slide 132](rendered_slides/MQ_Tech_Full-132.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- MAS-Seq: high-throughput, full-length single-cell sequencing
#
#
#
#
#                            Full-length, 10x
#                           single-cell cDNA
#
#
#
#
#                                                   MAS-Seq for 10x Single Cell 3’ kit
#                                                           (102-659-600)
#
#                                                       • 16x concatenation
#                              A                                                                             Q
#                                               B                 C        N                O            P
#                                        B’              C’           D’           O’               P’
#
#
#
#
#                                         A         B         C       D        N        O       P        Q
#
#
#
#
#  https://www.biorxiv.org/content/10.1101/2021.10.01.462818v1 -->

# %% [markdown]
# ![Slide 133](rendered_slides/MQ_Tech_Full-133.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Cell atlas, single-cell sequencing
#
#
#
#                                                                                                             3
#                                                         scRNA-Seq
#
#
#
#
#                             scIso-Seq
#
#
#       of human multi-exon                                                                                                          of brain expressed
#                                                                           isoforms per gene
# 95%   genes have more                                      >7             on average2                                    2,900     genes are heritable
#       than one isoform1                                                                                                            at isoform level4
#
#
#
#
#       1https://www.sciencedirect.com/science/article/pii/S2001037020305341;
#       2https://www.biorxiv.org/content/10.1101/2022.06.08.495354v1.full; 3https://www.pnas.org/doi/full/10.1073/pnas.2114326118;
#       4https://www.medrxiv.org/content/10.1101/2022.10.18.22281204v1 -->

# %% [markdown]
# ![Slide 134](rendered_slides/MQ_Tech_Full-134.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Comparison of PacBio with other
#          approaches -->

# %% [markdown]
# ![Slide 135](rendered_slides/MQ_Tech_Full-135.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Pacific BioSciences
#    Sequel/Revio Applications
# » Long read applications
# » De Novo sequencing
# » Full length cDNA sequenicng
# » Haplotyping
# » Variant calling with access to repetitive regions
#
#
# » DNA modification studies -->

# %% [markdown]
# ![Slide 136](rendered_slides/MQ_Tech_Full-136.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Pacific Biosciences
#
# » Single polymerase mol. in a 20nm hole
# » Watch incorporation in real time
# » ~2 bases per second
# » Yield 120Gb
# » ~$5-10/Gb
# » HiFi reads 15-20kb -->

# %% [markdown]
# ![Slide 137](rendered_slides/MQ_Tech_Full-137.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PacBio Onso
# ●   Released 2023
# ●   Most accurate short read
# ●   90%> Q40, Q50 possible
# ●   $99K current offer price
# ●   $4-12/Gb
# ●   100Gb/run
# ●   1x200 or 2 x 150 in 48hr
# ●   Sequencing by binding
# ●   Accuracy to 0.001% VAF
#     without UMIs -->

# %% [markdown]
# ![Slide 138](rendered_slides/MQ_Tech_Full-138.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Sequencing by Binding -->

# %% [markdown]
# ![Slide 139](rendered_slides/MQ_Tech_Full-139.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- SNV and Indel accuracy are better than any other
# platform -->

# %% [markdown]
# ![Slide 140](rendered_slides/MQ_Tech_Full-140.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- SBB demonstrates >4×                                 100%
#                                                                                  1.4x
#                                                                                sensitivity
# improvement in sequencing                            90%
#
# efficiency                                           80%
#
#                                                      70%
#
#                                                      60%
#
#
#
#
#                                        Sensitivity
#                                                      50%
#
#                                                      40%
#        6,000× non-UMI SBB sequencing
#        exceeds >24,000× SBS UMI                      30%
#        sequencing at 0.05% and 0.1%                                                                             SBB 6,000×
#                                                      20%                                                        SBS 24,000×
#
#                                                      10%
#
#                                                       0%
#                                                                    0             0.05              0.1            0.25              0.5
#
#                                                                               Variant allele %
#
#                                                        Data based on internal testing. >4× improvement in sequencing efficiency relative to SBS
#                                                                                                                                                   140 -->

# %% [markdown]
# ![Slide 141](rendered_slides/MQ_Tech_Full-141.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Nanopore Sequencing -->

# %% [markdown]
# ![Slide 142](rendered_slides/MQ_Tech_Full-142.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Oxford nanopore
#
# » Sequences single molecules of DNA as travel
#   through pore
#
# » Can also identify modified bases and
#   sequence RNA directly
#
# » Reads typically 5-50kb but some much longer
#   (4Mb record) -->

# %% [markdown]
# ![Slide 143](rendered_slides/MQ_Tech_Full-143.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 144](rendered_slides/MQ_Tech_Full-144.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 145](rendered_slides/MQ_Tech_Full-145.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT Simplex (1D) Library prep -->

# %% [markdown]
# ![Slide 146](rendered_slides/MQ_Tech_Full-146.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 147](rendered_slides/MQ_Tech_Full-147.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Flow cell design          Nanopore
#
#
#
#
# » Application-Specific Integrated
#   Circuits (ASICs), MinION ASIC
#   contains 512 channels
#                                              Synthetic
#                                              membrane
#
#
# » Each channel is surrounded
#  by 4 pores & records only 1
#                                            ASIC
#  at a time
#
# » 512 pores max recorded at the time -->

# %% [markdown]
# ![Slide 148](rendered_slides/MQ_Tech_Full-148.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Oxford Nanopore Technologies
#
#
#
#
#       Imagine 5-base words = 1024 current levels -->

# %% [markdown]
# ![Slide 149](rendered_slides/MQ_Tech_Full-149.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT: The squiggles
#
#
#
#
#      A G G T G C A T T G C T T G A G T T C T T T C A G T T A C T
#
#
#
#
# Slide courtesy of David Buck. WTCGH -->

# %% [markdown]
# ![Slide 150](rendered_slides/MQ_Tech_Full-150.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Assuming 5mer current signals
#
#
#
#
#     From Szalay & Golovchenko, Nat. Biotech., 2015. -->

# %% [markdown]
# ![Slide 151](rendered_slides/MQ_Tech_Full-151.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT basecalling with machine learning -->

# %% [markdown]
# ![Slide 152](rendered_slides/MQ_Tech_Full-152.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- R10. A dual head nanopore to help resolve
#              homopolymers
#
#
#  CsgF
#
#
#
#
# CsgG
#
#
#
#
#         From Van der Verren et al., Nature Biotech 2020 -->

# %% [markdown]
# ![Slide 153](rendered_slides/MQ_Tech_Full-153.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT Sequencing
# performance graphs -->

# %% [markdown]
# ![Slide 154](rendered_slides/MQ_Tech_Full-154.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT accuracy -->

# %% [markdown]
# ![Slide 155](rendered_slides/MQ_Tech_Full-155.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT accuracy -->

# %% [markdown]
# ![Slide 156](rendered_slides/MQ_Tech_Full-156.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT accuracy -->

# %% [markdown]
# ![Slide 157](rendered_slides/MQ_Tech_Full-157.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Direct sequencing of modifications -->

# %% [markdown]
# ![Slide 158](rendered_slides/MQ_Tech_Full-158.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- minION
# $1999. Yields upto 48Gb ~$5/Gb.
#           512pores. -->

# %% [markdown]
# ![Slide 159](rendered_slides/MQ_Tech_Full-159.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Connected minION
# Mk Ic
#         Mk Id based on ipad
#         pro -->

# %% [markdown]
# ![Slide 160](rendered_slides/MQ_Tech_Full-160.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- GridION. For service sector
#
#
#
#
# $67000 -->

# %% [markdown]
# ![Slide 161](rendered_slides/MQ_Tech_Full-161.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Flongle flow cell adapter
#     $90 for 2-3Gb -->

# %% [markdown]
# ![Slide 162](rendered_slides/MQ_Tech_Full-162.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PromethION
#             24 or 48 flowcells with 12000 pores
#
#
#
#
# ~$7-16/Gb -->

# %% [markdown]
# ![Slide 163](rendered_slides/MQ_Tech_Full-163.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- PromethION P2 Solo
#
#
#
#
# ~$7-16/Gb -->

# %% [markdown]
# ![Slide 164](rendered_slides/MQ_Tech_Full-164.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- ONT unique applications
#
# » Ultra-long reads (>100kb reads possible)
# » “Run until” done. W.I.M.P
# » Selective reads
# » Mobile sequencing
# » Direct RNA sequencing
# » Direct methylation detection over wide range
# of DNA and RNA modifications -->

# %% [markdown]
# ![Slide 165](rendered_slides/MQ_Tech_Full-165.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- So. Which to choose?
#
# » Budget
# » Technical fit
# » Applications
# » Throughput
# » Peers
# » Space -->

# %% [markdown]
# ![Slide 166](rendered_slides/MQ_Tech_Full-166.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!--  -->

# %% [markdown]
# ![Slide 167](rendered_slides/MQ_Tech_Full-167.jpg)
#
# <!-- SEARCHABLE TEXT CONTENT -->
# <!-- Any Questions ?
#
#    mq1@sanger.ac.uk -->
